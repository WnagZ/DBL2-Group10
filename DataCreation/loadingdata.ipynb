# %%
import csv
import pandas as pd

# %%
df_area = pd.read_csv("data.csv")
# Out:
# C:\Users\rbors\AppData\Local\Temp\ipykernel_9364\3038614085.py:1: DtypeWarning: Columns (2,11,12,14,15,16,17,19,20,21,22,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_area = pd.read_csv("data.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df_area['boroughs'] = df_area['LSOA name'].apply(lambda x: x.split(' ')[0] if pd.notnull(x) else x)

# %%
df_area2 = df_area[df_area['Type'].notnull()]
df_search = df_area2[['Longitude', 'Latitude', 'Type', 'Date', 'Gender', 'Age range', 'Self-defined ethnicity', 'Officer-defined ethnicity', 'Object of search', 'Outcome']]
df_search[df_search['Longitude'].notnull()].to_csv('Search.csv')

# %%
boroughs_list = [
    "Barking and Dagenham",
    "Barnet",
    "Bexley",
    "Brent",
    "Bromley",
    "Camden",
    "Croydon",
    "Ealing",
    "Enfield",
    "Greenwich",
    "Hackney",
    "Hammersmith and Fulham",
    "Haringey",
    "Harrow",
    "Havering",
    "Hillingdon",
    "Hounslow",
    "Islington",
    "Kensington and Chelsea",
    "Kingston upon Thames",
    "Lambeth",
    "Lewisham",
    "Merton",
    "Newham",
    "Redbridge",
    "Richmond upon Thames",
    "Southwark",
    "Sutton",
    "Tower Hamlets",
    "Waltham Forest",
    "Wandsworth",
    "Westminster"]

# %%
def check_borough(lsoa_name, boroughs_list):
    for borough in boroughs_list:
        if borough in lsoa_name:
            return borough
    return None

df_area['boroughs'] = df_area['LSOA name'].apply(lambda x: check_borough(x, boroughs_list) if pd.notnull(x) else x)

# %%
df_crimes = df_area[df_area['boroughs'].notna()]

# %%
df_crimes
# Out:
#           Unnamed: 0.1  Unnamed: 0  \
# 0                    0           0
# 1                    1           1
# 2                    2           2
# 3                    3           3
# 4                    4           4
# ...                ...         ...
# 23605977      23605977      191293
# 23605978      23605978      191294
# 23605979      23605979      191295
# 23605980      23605980      191296
# 23605981      23605981      191297
#
#                                                    Crime ID    Month  \
# 0                                                       NaN  2010-12
# 1                                                       NaN  2010-12
# 2                                                       NaN  2010-12
# 3                                                       NaN  2010-12
# 4                                                       NaN  2010-12
# ...                                                     ...      ...
# ...

# %%
dataframe = df_crimes[["Crime ID", "Month", "Crime type", "Last outcome category", "boroughs"]]
dataframe
# Out:
#                                                    Crime ID    Month  \
# 0                                                       NaN  2010-12
# 1                                                       NaN  2010-12
# 2                                                       NaN  2010-12
# 3                                                       NaN  2010-12
# 4                                                       NaN  2010-12
# ...                                                     ...      ...
# 23605977  cb73daf6b8479ac3c6f0393ccaed8ba09d656bc8ec7daf...  2024-01
# 23605978  9bf4d909cbf838f713421c29a173c1fd1578393789ce37...  2024-01
# 23605979  90ce6cc23afb135dcbc5eb17784b4d363375f9a076a2fd...  2024-01
# 23605980  be7a1b283771dc0aefcef2b191a4f7e91403771e1d6065...  2024-01
# 23605981  9006968a8e2fb5779017e7c6f1887ad21232b565cfe6df...  2024-01
#
#                             Crime type  \
# 0                Anti-social behaviour
# 1                Anti-social behaviour
# ...

# %%
dataframe.to_csv('crimes.csv')

# %%
df_search = df_area[df_area['Type'].notnull()]
df_search = df_search[['Longitude', 'Latitude', 'Type', 'Date', 'Gender', 'Age range', 'Self-defined ethnicity', 'Officer-defined ethnicity', 'Object of search', 'Outcome']]
df_search.to_csv('search.csv')
